# %%
import  pandas as pd

# %%
Customer = pd.read_csv(r'C:\Users\dhanw\OneDrive\Documents\EcommCustomers.csv')
Products = pd.read_csv(r'C:\Users\dhanw\OneDrive\Documents\EcommProducts.csv')
Orders = pd.read_csv(r'C:\Users\dhanw\OneDrive\Documents\EcommOrders.csv')
OrderDetails = pd.read_csv(r'C:\Users\dhanw\OneDrive\Documents\EcommOrderDetails.csv')
Engagement = pd.read_csv(r'C:\Users\dhanw\OneDrive\Documents\EcommEngagement.csv')

# %% [markdown]
# ### Showing First 10 records of the dataset

# %%
Customer.head(10)
# Out:
#    Customer_ID            Name  Gender  Age                       Email  \
# 0            1    Rohan Devare    Male   28      rohan.devare@gmail.com
# 1            2     Jiya Sharma  Female   34       jiya.sharma@gmail.com
# 2            3    Anaya Kapoor  Female   40      anaya.kapoor@yahoo.com
# 3            4  Namita Thappar  Female   28  namita.thappar@outlook.com
# 4            5     Akash Gupta    Male   31       akash.gupta@gmail.com
# 5            6     Sanya Verma  Female   29       sanya.verma@yahoo.com
# 6            7     Aarav Singh    Male   32       aarav.singh@gmail.com
# 7            8      Meera Iyer  Female   37        meera.iyer@gmail.com
# 8            9    Ritika Desai  Female   35      ritika.desai@gmail.com
# 9           10    Raghav Menon    Male   38    raghav.menon@outlook.com
#
#                                 Address    Lanuage    IP_Address  \
# 0        123 MG Road, Pune, Maharashtra      Hindi   192.168.2.1
# ...

# %%
Products.head(10)
# Out:
#    Product_ID Product_Name Product_Category  Product_Price
# 0        1001   Smartphone      Electronics         100.50
# 1        1002         Book            Books          45.99
# 2        1003      T-Shirt         Clothing         150.00
# 3        1004       Laptop      Electronics         750.00
# 4        1005   Desk Chair        Furniture         120.00
# 5        1006     Notebook       Stationery          20.50
# 6        1007     Backpack      Accessories          85.75
# 7        1008     Sneakers         Footwear         230.00
# 8        1009      Blender       Appliances         180.00
# 9        1010   Headphones      Electronics          90.00

# %%
Orders.head(10)
# Out:
#    Order_ID  Order_Date  Customer_ID                    Shipping_Address  \
# 0       101  01-12-2023            1             456 Elm St, Springfield
# 1       102  15-11-2023            2             123 Pine St, Metropolis
# 2       103  30-10-2023            3                789 Cedar St, Gotham
# 3       104  05-12-2023            4        10 MG Road, Bangalore, India
# 4       105  07-12-2023            5      50 Marine Drive, Mumbai, India
# 5       106  20-11-2023            6       67 Park Avenue, New York, USA
# 6       107  25-11-2023            7  22 Jubilee Hills, Hyderabad, India
# 7       108  19-10-2023            8        14 Salt Lake, Kolkata, India
# 8       109  03-12-2023            9             400 Oak St, Gotham, USA
# 9       110  30-11-2023           10             90 MG Road, Pune, India
#
#   Payment_Method Payment_Type AM or PM Order_Status     Lot          Company
# 0    Credit Card       Online       PM    Completed  Lot 46        Tech Corp
# ...

# %%
OrderDetails.head(10)
# Out:
#    Order_Details_ID  Order_ID  Product_ID  Quanity_Purchased  \
# 0                 1       101        1001                  2
# 1                 2       102        1002                  1
# 2                 3       103        1003                  3
# 3                 4       104        1004                  1
# 4                 5       105        1005                  4
# 5                 6       106        1006                  6
# 6                 7       107        1007                  2
# 7                 8       108        1008                  1
# 8                 9       109        1009                  3
# 9                10       110        1010                  2
#
#    Discount_Applied  Purchase_Price
# 0              10.0          150.75
# 1               5.0           89.99
# 2              15.0          250.00
# 3              20.0          730.00
# 4              25.0          450.00
# 5               2.5          115.00
# ...

# %%
Engagement.head(10)
# Out:
#    Engagement_ID  Customer_ID Device_Type  Session_Duration Referral_Source  \
# 0              1            1     Desktop               300          Google
# 1              2            2      Mobile               120    Social Media
# 2              3            3      Tablet               200          Direct
# 3              4            4      Mobile               150          Google
# 4              5            5     Desktop               400           Email
# 5              6            6      Tablet               250    Social Media
# 6              7            7      Mobile               100          Google
# 7              8            8     Desktop               320        Referral
# 8              9            9      Tablet               180          Direct
# 9             10           10      Mobile                90          Google
#
#    Customer_Rating  Delivery_Time
# 0              4.5              5
# 1              4.8              7
# ...

# %% [markdown]
# ### Last 5 records of the dataset

# %%
print(Customer.tail(5))
print(Products.tail(5))
print(Orders.tail(5))
print(OrderDetails.tail(5))
print(Engagement.tail(5))
# Out:
#     Customer_ID           Name  Gender  Age                      Email  \
# 20           21  Sophia Taylor  Female   29    sophia.taylor@yahoo.com
# 21           22  Michael Scott    Male   45  michael.scott@outlook.com
# 22           23   Kavya Pillai  Female   31     kavya.pillai@gmail.com
# 23           24   Ishaan Arora    Male   28     ishaan.arora@yahoo.com
# 24           25  Rina Banerjee  Female   35  rina.banerjee@outlook.com
#
#                                  Address    Lanuage    IP_Address  \
# 20           777 Elm Street, Dallas, USA    English  192.168.2.21
# 21       401 Scranton Ave, Scranton, USA    English  192.168.2.22
# 22         22 MG Road, Ernakulam, Kerala  Malayalam  192.168.2.23
# 23              71 Sector 21, Chandigarh      Hindi  192.168.2.24
# 24  60 Park Street, Kolkata, West Bengal    Bengali  192.168.2.25
#
#     Browser_Info
# 20   Safari/15.2
# 21    Binge/13.0
# 22   Chrome/96.0
# 23  Firefox/93.0
# 24   Safari/18.0
# ...

# %% [markdown]
# ### Checking Data types of columns in each table

# %%
'''printing all datatype at once'''

print(Customer.dtypes)
print(Products.dtypes)
print(Orders.dtypes)
print(OrderDetails.dtypes)
print(Engagement.dtypes)
# Out:
# Customer_ID      int64
# Name            object
# Gender          object
# Age              int64
# Email           object
# Address         object
# Lanuage         object
# IP_Address      object
# Browser_Info    object
# dtype: object
# Product_ID            int64
# Product_Name         object
# Product_Category     object
# Product_Price       float64
# dtype: object
# Order_ID             int64
# Order_Date          object
# Customer_ID          int64
# Shipping_Address    object
# Payment_Method      object
# Payment_Type        object
# AM or PM            object
# Order_Status        object
# Lot                 object
# Company             object
# dtype: object
# Order_Details_ID       int64
# Order_ID               int64
# Product_ID             int64
# Quanity_Purchased      int64
# Discount_Applied     float64
# Purchase_Price       float64
# dtype: object
# Engagement_ID         int64
# Customer_ID           int64
# Device_Type          object
# ...

# %% [markdown]
# ### Checking Null Values in each tables

# %%
Customer.isnull().sum()
# Out:
# Customer_ID     0
# Name            0
# Gender          0
# Age             0
# Email           0
# Address         0
# Lanuage         0
# IP_Address      0
# Browser_Info    0
# dtype: int64

# %%
Products.isnull().sum()
# Out:
# Product_ID          0
# Product_Name        0
# Product_Category    0
# Product_Price       0
# dtype: int64

# %%
Orders.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Shipping_Address    0
# Payment_Method      0
# Payment_Type        0
# AM or PM            0
# Order_Status        0
# Lot                 0
# Company             0
# dtype: int64

# %%
OrderDetails.isnull().sum()
# Out:
# Order_Details_ID     0
# Order_ID             0
# Product_ID           0
# Quanity_Purchased    0
# Discount_Applied     0
# Purchase_Price       0
# dtype: int64

# %%
Engagement.isnull().sum()
# Out:
# Engagement_ID       0
# Customer_ID         0
# Device_Type         0
# Session_Duration    0
# Referral_Source     0
# Customer_Rating     0
# Delivery_Time       0
# dtype: int64

# %% [markdown]
# ###  Columns and Rows are in our Datasets ?

# %%
print("Customer Column", len(Customer.columns))
print("Customer Rows", len(Customer))

print("Product Columns",len(Products.columns))
print("Product Rows",len(Products))

print("Orders Columns",len(Orders.columns))
print("Orders Rows",len(Orders))

print("OrderDetails Columns",len(OrderDetails.columns))
print("OrderDetails Rows",len(OrderDetails))

print("Engagement Columns",len(Engagement.columns))
print("Engagement Rows",len(Engagement))
# Out:
# Customer Column 9
# Customer Rows 25
# Product Columns 4
# Product Rows 25
# Orders Columns 10
# Orders Rows 25
# OrderDetails Columns 6
# OrderDetails Rows 25
# Engagement Columns 7
# Engagement Rows 25

# %%
Customer.info()
Products.info()
Orders.info()
OrderDetails.info()
Engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Customer_ID   25 non-null     int64
#  1   Name          25 non-null     object
#  2   Gender        25 non-null     object
#  3   Age           25 non-null     int64
#  4   Email         25 non-null     object
#  5   Address       25 non-null     object
#  6   Lanuage       25 non-null     object
#  7   IP_Address    25 non-null     object
#  8   Browser_Info  25 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 1.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        25 non-null     int64
#  1   Product_Name      25 non-null     object
#  2   Product_Category  25 non-null     object
# ...

# %% [markdown]
# ### Highest and Lowest Purchase Prices and Product Price

# %%
#product price
H_price = Products['Product_Price'].max()
L_price = Products['Product_Price'].min()

# %%
'Highest Procuct Price is ',H_price
# Out:
# ('Highest Procuct Price is ', 980.0)

# %%
print('Lowest Product Price is', L_price)
# Out:
# Lowest Product Price is 12.75

# %%
#Purchase Price
H_purchase = OrderDetails['Purchase_Price'].max()
L_purchase = OrderDetails['Purchase_Price'].min()

# %%
print('Highest Purchase Price is', H_purchase)
print('Lowest Purchase Price is', L_purchase)
# Out:
# Highest Purchase Price is 900.0
# Lowest Purchase Price is 33.75

# %% [markdown]
# ### Average Purchase Price

# %%
Avg = OrderDetails['Purchase_Price'].mean()
Avg
# Out:
# 272.2896

# %% [markdown]
# ### How many people have Hindi as their language ?

# %%
len(Customer[Customer['Lanuage']=='Hindi'])
# Out:
# 6

# %% [markdown]
# ### Find out Company titles that contains Books

# %%
Filter = Orders[Orders['Company'].str.contains('Book',case=False)]

# %%
Filter
# Out:
#     Order_ID  Order_Date  Customer_ID             Shipping_Address  \
# 1        102  15-11-2023            2      123 Pine St, Metropolis
# 8        109  03-12-2023            9      400 Oak St, Gotham, USA
# 20       121  05-10-2023           21  777 Elm Street, Dallas, USA
#
#    Payment_Method Payment_Type AM or PM Order_Status     Lot        Company
# 1          PayPal       Online       AM      Pending  Lot 28     Book World
# 8          PayPal       Online       PM    Delivered  Lot 41     Book Haven
# 20         PayPal       Online       PM    Cancelled  Lot 18  Book Paradise

# %%
len(Filter)
# Out:
# 3

# %%
len(Products[Products['Product_Category'].str.contains('Electronics',case=False)])
# Out:
# 7

# %% [markdown]
# ### Sorting Products Category Alphabetical Order

# %%
Sort = Products.sort_values(by='Product_Category', ascending=True)

# %%
Sort
# Out:
#     Product_ID       Product_Name Product_Category  Product_Price
# 6         1007           Backpack      Accessories          85.75
# 18        1019              Watch      Accessories         150.00
# 10        1011         Sunglasses      Accessories          65.25
# 8         1009            Blender       Appliances         180.00
# 13        1014    Electric Kettle       Appliances          55.00
# 1         1002               Book            Books          45.99
# 2         1003            T-Shirt         Clothing         150.00
# 20        1021      Winter Jacket         Clothing         400.00
# 23        1024         Wall Clock            Decor          35.99
# 0         1001         Smartphone      Electronics         100.50
# 21        1022  Bluetooth Speaker      Electronics         120.00
# 19        1020      Action Camera      Electronics         300.00
# 15        1016       Gaming Mouse      Electronics          35.50
# ...

# %% [markdown]
# ### Discounts more than 20

# %%
Discounts = OrderDetails[OrderDetails['Discount_Applied']>20]
Discounts.sort_values('Discount_Applied')
# Out:
#     Order_Details_ID  Order_ID  Product_ID  Quanity_Purchased  \
# 4                  5       105        1005                  4
# 22                23       123        1023                  1
# 7                  8       108        1008                  1
# 19                20       120        1020                  1
# 14                15       115        1015                  1
# 20                21       121        1021                  2
# 24                25       125        1025                  1
#
#     Discount_Applied  Purchase_Price
# 4               25.0           450.0
# 22              25.0           150.0
# 7               30.0           200.0
# 19              40.0           270.0
# 14              50.0           620.0
# 20              50.0           750.0
# 24              80.0           900.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

device_usage = Engagement['Device_Type'].value_counts()

# Pie Chart
device_usage.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(4, 4))
plt.title("Customer Device Usage")
plt.ylabel("")
plt.show()
